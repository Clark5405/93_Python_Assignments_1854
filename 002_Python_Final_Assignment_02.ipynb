# %% [markdown]
#     JLUFE                                                     Spring 2021 (Feb-July)
#
#                              Final Assignment Report
#
#
#                      JILIN UNIVERSITY OF FINANCE AND ECONOMICS
#
#       Department of College of Managment Science and Information Engineering
#
#                     Information Management and Information Systems
#
#                                      (2021)
#
#
#
#                             Final Assignment: Part 02
#
#                                    13/07/2021
#
#                                MODULE: Data Mining
#
#                   Submitted by: Bradley(李建坤) 0314021805404 (1854)
#                                     QQ: 321330948   Github ID: Bradley13596181300
#                                 Clark(郭旭) 0314021805405 (1854)
#                                     QQ: 1145673148   Github ID: Clark5405

# %% [markdown]
# # Instructions:
#
# 1. I have added tips and required learning resources for each question, which helps you to solve the exercise.
#
# 2. Finish the assignment in **group of two students (Any group find copying/sharing from another group or internet will get '0' points!!!**)
#
# 3. **Accept this assignment** from the **[Github Clasroom link](https://classroom.github.com/a/yFXO50A4)** This will create private repository of the assignment in your Github account.
#
# 4. In your repository **`Clone`** -> **`Download ZIP`** in your computer.
#
# 5. Change your: **Major**, **Name**, **Student number**, **Class number**, **QQ number** and **GitHub ID**
#
# 6. Once you finish the Assignment **[convert your .ipynb file into PDF](https://github.com/milaan9/91_Python_Tips/blob/main/000_Convert_Jupyter_Notebook_to_PDF.ipynb)** (both .pynb and .pdf file will be required!)
#
# 7. Create Folder name "**Solution**" and copy your 3 files:
#     1. Your Jupyter Notebook file (**.ipynb**).
#     2. Your PDF converted file (**.pdf**).
#     3. **.zip** file containing both .ipynb and .pdf files and name your .zip file as your student number and name. For example: **0318021907632-3086215267 Milan(米兰)-Nina(妮娜).zip**
#
# 8. Finally, in your repository **`Add files`** -> **`upload files`** upload the "**Solution**" folder and **`Commit changes`**.

# %% [markdown]
# # Python Assignment 02

# %% [markdown]
# ### Question: Hangman Game
#
# Write a python program to create a Hangman game.
#
# **About Game:**
# Going back to our old school days, some of the pen-paper games were always a top for our leisure time. In Hangman user has to guess words according to the guesses determined and as soon as they lost all their wrong guesses, they were hanged (not really, but on paper 😉).
# In the game of Hangman, the player only has 7 incorrect guesses (head, body, 2 legs, and 2 arms, hang) before they lose the game.
#
# **Structure:**
# 1. In Part 1, you will require to load a random word from a **[dictionary](https://github.com/milaan9/92_Python_Assignments/blob/main/sowpods.txt)**.
# 2. In Part 2, you will require the logic for guessing the letter and displaying that information to the user.
#
# After completing part 1 and part 2 you will need to add the following features:
#
# **Features:**
# * Only let the user guess 7 times, and tell the user how many guesses they have left. Example: "You have 6 guesses left!"
# * No restriction in uppercase and lowercase letters.
#     - Example: user can guess "a" and it will be equal to "A" or vice-versa.
# * If user guesses a numbers or a special characters, don’t penalize them - ask them again to choose only letter.
#     - Example: user guess "9" or "?" then ask user again to choose a letter.
# * If the guess letter appear more than one time in the word display it.
#     - Example: Word is "Apple" and user guess the word 'p' so  -->     __ P  P  __  __
# * Keep track of the letters the user guessed incorrectly. If the user guesses a letter they already guessed, don’t penalize them - let them guess again.
# * Display some picture art for the Hangman. This is challenging - do the other parts of the exercise first!
# * When the player wins or loses, let them start a new game.

# %% [markdown]
# **Expected/Similar Output:**
#
# ```
# ***********************
# Welcome to Hangman!
# ***********************
# Guess one letter at a time
# Game is not case sensitive
#
# __ __ __ __ __ __ __ __
#
# What is your guess?: a
#
# __  A  __ __  A  __ __ __
#
# What is your guess?: 9
# Please chose just a letter: e
# e is not in this word!
#    ____
#   |    |
#
# You have 6 guesses left!
# your previous wrong guesses: ['E']
#
# __  A  __ __  A  __ __ __
#
# What is your guess?: e
# You have already guessed e!
#
# __  A  __ __  A  __ __ __
#
# What is your guess?: h
# h is not in this word!
#    ____
#   |    |
#   |    O
#   |    |
#
# You have 5 guesses left!
# your previous wrong guesses: ['E', 'H']
#
# __  A  __ __  A  __ __ __
#
# What is your guess?: d
# d is not in this word!
#    ____
#   |    |
#   |    O
#   |   /|
#
# You have 4 guesses left!
# your previous wrong guesses: ['E', 'H', 'D']
#
# __  A  __ __  A  __ __ __
#
# What is your guess?: b
# b is not in this word!
#    ____
#   |    |
#   |    O
#   |   /|\
#
# You have 3 guesses left!
# your previous wrong guesses: ['E', 'H', 'D', 'B']
#
# __  A  __ __  A  __ __ __
#
# What is your guess?: k
#
# K  A  __ __  A  __ __ __
#
# What is your guess?: r
#
# K  A  __ __  A  R __ __
#
# What is your guess?: t
# t is not in this word!
#
#    ____
#   |    |
#   |    O
#   |   /|\
#   |   /
#
# You have 2 guesses left!
# your previous wrong guesses: ['E', 'H', 'D', 'B', 'T']
#
# K  A  __ __  A  R __ __
#
# What is your guess?: l
# l is not in this word!
#
#    ____
#   |    |
#   |    O
#   |   /|\
#   |   / \
#
# You have 1 guesses left!
# your previous wrong guesses: ['E', 'H', 'D', 'B', 'T', 'L']
#
# K  A  __ __  A  R __ __
#
# What is your guess?: p
# p is not in this word!
#
#    ____
#   |    |
#   |    |
#   |    O
#   |   /|\
#   |   / \
# __|__
#
# You have 0 guesses left!
# You lose!
# your previous wrong guesses: ['E', 'H', 'D', 'B', 'T', 'L', 'P']
#
# The word was  ['K', 'A', 'N', 'G', 'A', 'R', 'O', 'O']
#
# Would you like to play again? [y|n]: n
#
# ```

# %%
# Solution:
import random
import string
def plot(count):
    if count==6:
        print('  ____')
        print(' |'+ '    '+'|')
    elif count==5:
        print('  ____')
        print(' |'+ '    '+'|')
        print(' |'+ '    '+'0')
        print(' |'+ '    '+'|')
    elif count==4:
        print('  ____')
        print(' |'+ '    '+'|')
        print(' |'+ '    '+'0')
        print(' |'+ '   '+'/'+'|')
    elif count==3:
        print('  ____')
        print(' |'+ '    '+'|')
        print(' |'+ '    '+'0')
        print(' |'+ '   '+'/'+'|'+'\\')
    elif count==2:
        print('  ____')
        print(' |'+ '    '+'|')
        print(' |'+ '    '+'0')
        print(' |'+ '   '+'/'+'|'+'\\')
        print(' |'+ '   '+'/')
    elif count==1:
        print('  ____')
        print(' |'+ '    '+'|')
        print(' |'+ '    '+'0')
        print(' |'+ '   '+'/'+'|'+'\\')
        print(' |'+ '   '+'/'+' '+'\\')
    elif count==0:
        print('   ____')
        print('  |'+ '    '+'|')
        print('  |'+ '    '+'|')
        print('  |'+ '    '+'0')
        print('  |'+ '   '+'/'+'|'+'\\')
        print('  |'+ '   '+'/'+' '+'\\')
        print('__|__ ')
file_read=open('sowpods.txt',mode='r')
text=file_read.readlines()
flag0=0
while flag0==0:
    random_word = text[random.randint(0, len(text))].replace('\n','')
    word_number = len(random_word)
    count=7
    print('*'*23)
    print('Welcome to Hangman!')
    print('*'*23)
    print('Guess one letter at a time')
    print('Game is not case sensitive')
    answer_word_list  = ['_ '  for i in range(word_number)]
    flag =0
    wrong_guesses=[]
    while flag ==0:
        print(''.join(answer_word_list))
        a = input('What is your guess?: ')
        b=a.upper()
        if not b.isalpha():
            flag1=0
            while flag1 ==0:
                a = input('Please chose just a letter: ')
                b=a.upper()
                if b.isalpha():
                    flag1 =1
        if b in wrong_guesses:
            print('You have already guessed {}!'.format(a))
            continue
        if b in random_word:
            index_list = [i for i,x in enumerate(random_word) if x ==b]
            for i in index_list:
                answer_word_list[i]=b
            if not '_ ' in answer_word_list:
                print('You success!')
                again1 = input('Would you like to play again? [y|n]: ')
                if again1=='n':
                    flag0 =1
                    flag = 1
                else:
                    flag = 1
        else:
            print(b+' is not in this word!')
            count -= 1
            plot(count)
            print('You have {} guesses left!'.format(count))
            wrong_guesses.append(b)
            if count ==0:
                print('You lose!')
                print('your previous wrong guesses: '+str(wrong_guesses))
                print(str([i for i in random_word]))
                again1 = input('Would you like to play again? [y|n]: ')
                if again1=='n':
                    flag0 =1
                    flag = 1
                else:
                    flag = 1
            else:
                print('your previous wrong guesses: '+str(wrong_guesses))
# Out:
# ***********************
# Welcome to Hangman!
# ***********************
# Guess one letter at a time
# Game is not case sensitive
# _ _ _ _ _ _
# What is your guess?: a
# A is not in this word!
#   ____
#  |    |
# You have 6 guesses left!
# your previous wrong guesses: ['A']
# _ _ _ _ _ _
# What is your guess?: 9
# Please chose just a letter: e
# _ _ _ _ _ E
# What is your guess?: h
# _ H_ _ _ E
# What is your guess?: d
# D is not in this word!
#   ____
#  |    |
#  |    0
#  |    |
# You have 5 guesses left!
# your previous wrong guesses: ['A', 'D']
# _ H_ _ _ E
# What is your guess?: b
# _ H_ B_ E
# What is your guess?: k
# K is not in this word!
#   ____
#  |    |
#  |    0
#  |   /|
# You have 4 guesses left!
# your previous wrong guesses: ['A', 'D', 'K']
# _ H_ B_ E
# What is your guess?: r
# R is not in this word!
#   ____
#  |    |
#  |    0
#  |   /|\
# You have 3 guesses left!
# your previous wrong guesses: ['A', 'D', 'K', 'R']
# _ H_ B_ E
# What is your guess?: t
# TH_ B_ E
# What is your guess?: l
# TH_ BLE
# What is your guess?: p
# P is not in this word!
#   ____
#  |    |
#  |    0
#  |   /|\
#  |   /
# You have 2 guesses left!
# your previous wrong guesses: ['A', 'D', 'K', 'R', 'P']
# TH_ BLE
# What is your guess?: c
# C is not in this word!
#   ____
#  |    |
#  |    0
#  |   /|\
#  |   / \
# You have 1 guesses left!
# your previous wrong guesses: ['A', 'D', 'K', 'R', 'P', 'C']
# TH_ BLE
# What is your guess?: s
# S is not in this word!
#    ____
#   |    |
#   |    |
#   |    0
#   |   /|\
#   |   / \
# __|__
# You have 0 guesses left!
# You lose!
# your previous wrong guesses: ['A', 'D', 'K', 'R', 'P', 'C', 'S']
# ['T', 'H', 'I', 'B', 'L', 'E']
# Would you like to play again? [y|n]: n
